# %% [markdown]
# ### Datasets:
#
# Here's one dataset for food prices https://www.kaggle.com/jboysen/global-food-prices
#
# Here is the dataset for temperature and rainfalls http://sdwebx.worldbank.org/climateportal/index.cfm?page=downscaled_data_download&menu=historical

# %% [markdown]
# ### Hypothesis:
#
# Do changes in average temperature and average level of rainfall affect the change in the average price on X crop in X country in X-X years

# %% [markdown]
# ### Questions to the Professor:
#
# 1. How can we all access and work simultaneously in the shared Github repo (with 1 master and 3 collaborators)?

# %% [markdown]
# # Cleaning the data
# coding issues- utf-8 didn't work, use iso-8859-1 instead

# %%
import pandas as pd

CsvFile='https://raw.githubusercontent.com/vzakhozhyi/599-A-Final-Project/master/Data/wfp_market_food_prices.csv'
##
dataCsv=pd.read_csv(CsvFile,header=0, encoding = "ISO-8859-1")

# %%
dataCsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743914 entries, 0 to 743913
# Data columns (total 18 columns):
# adm0_id               743914 non-null int64
# adm0_name             743914 non-null object
# adm1_id               743914 non-null int64
# adm1_name             729965 non-null object
# mkt_id                743914 non-null int64
# mkt_name              743914 non-null object
# cm_id                 743914 non-null int64
# cm_name               743914 non-null object
# cur_id                743914 non-null int64
# cur_name              743914 non-null object
# pt_id                 743914 non-null int64
# pt_name               743914 non-null object
# um_id                 743914 non-null int64
# um_name               743914 non-null object
# mp_month              743914 non-null int64
# mp_year               743914 non-null int64
# mp_price              743914 non-null float64
# mp_commoditysource    743914 non-null object
# dtypes: float64(1), int64(9), object(8)
# memory usage: 102.2+ MB

# %%
dataCsv.adm0_name.unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Armenia', 'Azerbaijan', 'Bangladesh',
#        'Benin', 'Bhutan', 'Bolivia', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Cape Verde', 'Central African Republic',
#        'Chad', 'Colombia', 'Congo', 'Costa Rica', "Cote d'Ivoire",
#        'Democratic Republic of the Congo', 'Djibouti', 'El Salvador',
#        'Ethiopia', 'Gambia', 'Georgia', 'Ghana', 'Guatemala',
#        'Guinea-Bissau', 'Guinea', 'Haiti', 'Honduras', 'India',
#        'Indonesia', 'Iran  (Islamic Republic of)', 'Iraq', 'Jordan',
#        'Kenya', 'Kyrgyzstan', "Lao People's Democratic Republic",
#        'Lebanon', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Mozambique', 'Myanmar', 'Nepal', 'Niger', 'Nigeria',
#        'Pakistan', 'Panama', 'Peru', 'Philippines', 'Rwanda', 'Senegal',
#        'Somalia', 'Sri Lanka', 'Swaziland', 'Syrian Arab Republic',
#        'Tajikistan', 'Timor-Leste', 'Turkey', 'Uganda', 'Ukraine',
#        'United Republic of Tanzania', 'Yemen', 'Zambia', 'Zimbabwe',
#        'State of Palestine', 'Sudan', 'Egypt', 'South Sudan'],
#       dtype=object)

# %%
#CountryWeWant = ['Cambodia', "Lao People's Democratic Republic", 'Myanmar']

# %%
TargetCountry = ['Bolivia', "Peru", 'Colombia']
TargetCrop = ["Potatoes"]

# %% [markdown]
# Let's see what we have.

# %%
#dataCsv.head

# %%
#dataCsv.tail

# %% [markdown]
# #pd.unique(demodexClean.Category).tolist()

# %%
#price = dataCsv[adm0_name == 'Afghanistan']

# %%
#dataCsv.query(adm0_name)

# %%
Price = dataCsv[dataCsv.adm0_name.isin(CountryWeWant)]

# %% [markdown]
# See unique values of crops of each country.

# %%
Price[(Price.adm0_name=='Bolivia')].cm_name.unique()
# Out:
# array(['Eggs', 'Sugar', 'Meat (beef, chops with bones)',
#        'Meat (chicken, whole)', 'Noodles (short)', 'Potatoes (Dutch)',
#        'Potatoes (Irish, imilla)', 'Rice (estaquilla)',
#        'Rice (long grain)', 'Bread (wheat)', 'Rice (good quality)',
#        'Rice (white)', 'Rice (carolina 2da)', 'Rice (medium grain)',
#        'Potatoes (black)'], dtype=object)

# %%
Price[(Price.adm0_name== "Peru")].cm_name.unique()
# Out:
# array(['Maize (local)', 'Rice (local)', 'Potatoes', 'Meat (chicken)',
#        'Oil (vegetable)', 'Sugar', 'Wheat flour (locally processed)'],
#       dtype=object)

# %%
Price[(Price.adm0_name== 'Colombia')].cm_name.unique()
# Out:
# array(['Wheat flour', 'Maize (white)', 'Maize flour', 'Beans (red)',
#        'Potatoes', 'Meat (chicken)', 'Oil (vegetable)', 'Sugar', 'Garlic',
#        'Onions (red)', 'Onions (white)', 'Pasta', 'Tomatoes',
#        'Rice (white)', 'Maize (yellow)', 'Meat (beef)', 'Plantains',
#        'Cocoa', 'Coffee', 'Carrots', 'Fish (dry)', 'Cabbage', 'Salt',
#        'Rice (paddy)', 'Chickpeas (imported)', 'Eggs (white, AA)',
#        'Meat (beef, minced)', 'Peas (green, dry)', 'Potatoes (unica)',
#        'Sugar (brown)', 'Sugar (brown, loaf)', 'Apples (red)',
#        'Cauliflower', 'Cucumbers (greenhouse)', 'Oranges (big size)',
#        'Bananas', 'Beans (red, fresh)', 'Fuel (diesel)',
#        'Fuel (petrol-gasoline)', 'Cassava (dry)', 'Spinach',
#        'Fish (tilapia)', 'Beans (string)', 'Guava', 'Papaya',
#        'Blackberry', 'Broccoli', 'Mangoes', 'Pumpkin',
#        'Tamarillos/tree tomatoes', 'Cheese', 'Lentils (imported)',
#        'Milk (pasteurized)',
#        'Wage (non-qualified labour, non-agricultural)', 'Meat (pork)',
#        'Coffee (instant)', 'Oil (sunflower)'], dtype=object)

# %%
#targetCountry = ['Ghana']
#GhanaPrice = dataCsv[dataCsv.adm0_name.isin(targetCountry)]
#GhanaPrice.info()
#data1 = GhanaPrice[GhanaPrice.mp_year == 2015]

# %%
# This is what you want get rid of:
ByeColumns = ['adm0_id', 'adm1_id','mkt_id','cm_id','cur_id','pt_id','um_id']#,'mp_commoditysource']

#this would change the original: GhanaYamPrice.drop(byeColumns,axis=1,inplace=False)
Price=Price.drop(ByeColumns,axis=1, inplace=False).reset_index(drop=True)

# %%
Price
# Out:
#       adm0_name   adm1_name mkt_name                          cm_name  \
# 0       Bolivia  Chuquisaca    Sucre                             Eggs
# 1       Bolivia  Chuquisaca    Sucre                             Eggs
# 2       Bolivia  Chuquisaca    Sucre                             Eggs
# 3       Bolivia  Chuquisaca    Sucre                             Eggs
# 4       Bolivia  Chuquisaca    Sucre                             Eggs
# 5       Bolivia  Chuquisaca    Sucre                             Eggs
# 6       Bolivia  Chuquisaca    Sucre                             Eggs
# 7       Bolivia  Chuquisaca    Sucre                             Eggs
# 8       Bolivia  Chuquisaca    Sucre                             Eggs
# 9       Bolivia  Chuquisaca    Sucre                             Eggs
# 10      Bolivia  Chuquisaca    Sucre                             Eggs
# 11      Bolivia  Chuquisaca    Sucre                             Eggs
# 12      Bolivia  Chuquisaca    Sucre                             Eggs
# 13      Bolivia  Chuquisaca    Sucre                             Eggs
# 14      Bolivia  Chuquisaca    Sucre                             Eggs
# 15      Bolivia  Chuquisaca    Sucre                             Eggs
# 16      Bolivia  Chuquisaca    Sucre                             Eggs
# 17      Bolivia  Chuquisaca    Sucre                             Eggs
# 18      Bolivia  Chuquisaca    Sucre                             Eggs
# 19      Bolivia  Chuquisaca    Sucre                             Eggs
# 20      Bolivia  Chuquisaca    Sucre                             Eggs
# 21      Bolivia  Chuquisaca    Sucre                             Eggs
# 22      Bolivia  Chuquisaca    Sucre                             Eggs
# 23      Bolivia  Chuquisaca    Sucre                             Eggs
# 24      Bolivia  Chuquisaca    Sucre                             Eggs
# 25      Bolivia  Chuquisaca    Sucre                             Eggs
# 26      Bolivia  Chuquisaca    Sucre                            Sugar
# 27      Bolivia  Chuquisaca    Sucre                            Sugar
# 28      Bolivia  Chuquisaca    Sucre                            Sugar
# 29      Bolivia  Chuquisaca    Sucre                            Sugar
# ...         ...         ...      ...                              ...
# 13596      Peru        Lima     Lima  Wheat flour (locally processed)
# 13597      Peru        Lima     Lima  Wheat flour (locally processed)
# 13598      Peru        Lima     Lima  Wheat flour (locally processed)
# 13599      Peru        Lima     Lima  Wheat flour (locally processed)
# 13600      Peru        Lima     Lima  Wheat flour (locally processed)
# 13601      Peru        Lima     Lima  Wheat flour (locally processed)
# 13602      Peru        Lima     Lima  Wheat flour (locally processed)
# 13603      Peru        Lima     Lima  Wheat flour (locally processed)
# 13604      Peru        Lima     Lima  Wheat flour (locally processed)
# 13605      Peru        Lima     Lima  Wheat flour (locally processed)
# 13606      Peru        Lima     Lima  Wheat flour (locally processed)
# 13607      Peru        Lima     Lima  Wheat flour (locally processed)
# 13608      Peru        Lima     Lima  Wheat flour (locally processed)
# 13609      Peru        Lima     Lima  Wheat flour (locally processed)
# 13610      Peru        Lima     Lima  Wheat flour (locally processed)
# 13611      Peru        Lima     Lima  Wheat flour (locally processed)
# 13612      Peru        Lima     Lima  Wheat flour (locally processed)
# 13613      Peru        Lima     Lima  Wheat flour (locally processed)
# 13614      Peru        Lima     Lima  Wheat flour (locally processed)
# 13615      Peru        Lima     Lima  Wheat flour (locally processed)
# 13616      Peru        Lima     Lima  Wheat flour (locally processed)
# 13617      Peru        Lima     Lima  Wheat flour (locally processed)
# 13618      Peru        Lima     Lima  Wheat flour (locally processed)
# 13619      Peru        Lima     Lima  Wheat flour (locally processed)
# 13620      Peru        Lima     Lima  Wheat flour (locally processed)
# 13621      Peru        Lima     Lima  Wheat flour (locally processed)
# 13622      Peru        Lima     Lima  Wheat flour (locally processed)
# 13623      Peru        Lima     Lima  Wheat flour (locally processed)
# 13624      Peru        Lima     Lima  Wheat flour (locally processed)
# 13625      Peru        Lima     Lima  Wheat flour (locally processed)
#
#       cur_name pt_name um_name  mp_month  mp_year  mp_price  \
# 0          BOB  Retail    Unit         4     2015      0.72
# 1          BOB  Retail    Unit         5     2015      0.73
# 2          BOB  Retail    Unit         6     2015      0.76
# 3          BOB  Retail    Unit         7     2015      0.76
# 4          BOB  Retail    Unit         8     2015      0.74
# 5          BOB  Retail    Unit         9     2015      0.73
# 6          BOB  Retail    Unit        10     2015      0.73
# 7          BOB  Retail    Unit        11     2015      0.71
# 8          BOB  Retail    Unit        12     2015      0.71
# 9          BOB  Retail    Unit         1     2016      0.70
# 10         BOB  Retail    Unit         2     2016      0.70
# 11         BOB  Retail    Unit         3     2016      0.71
# 12         BOB  Retail    Unit         4     2016      0.71
# 13         BOB  Retail    Unit         5     2016      0.72
# 14         BOB  Retail    Unit         6     2016      0.73
# 15         BOB  Retail    Unit         7     2016      0.72
# 16         BOB  Retail    Unit         8     2016      0.72
# 17         BOB  Retail    Unit         9     2016      0.72
# 18         BOB  Retail    Unit        10     2016      0.71
# 19         BOB  Retail    Unit        12     2016      0.69
# 20         BOB  Retail    Unit         1     2017      0.68
# 21         BOB  Retail    Unit         2     2017      0.66
# 22         BOB  Retail    Unit         3     2017      0.68
# 23         BOB  Retail    Unit         4     2017      0.69
# 24         BOB  Retail    Unit         5     2017      0.71
# 25         BOB  Retail    Unit         6     2017      0.72
# 26         BOB  Retail      KG         4     2015      6.31
# 27         BOB  Retail      KG         5     2015      6.27
# 28         BOB  Retail      KG         6     2015      6.27
# 29         BOB  Retail      KG         7     2015      6.27
# ...        ...     ...     ...       ...      ...       ...
# 13596      PEN  Retail      KG         2     2014      3.87
# 13597      PEN  Retail      KG         3     2014      3.91
# 13598      PEN  Retail      KG         4     2014      3.91
# 13599      PEN  Retail      KG         5     2014      3.91
# 13600      PEN  Retail      KG         6     2014      3.91
# 13601      PEN  Retail      KG         7     2014      3.91
# 13602      PEN  Retail      KG         8     2014      3.92
# 13603      PEN  Retail      KG         9     2014      3.92
# 13604      PEN  Retail      KG        10     2014      3.93
# 13605      PEN  Retail      KG        11     2014      3.93
# 13606      PEN  Retail      KG        12     2014      3.94
# 13607      PEN  Retail      KG         1     2015      3.95
# 13608      PEN  Retail      KG         2     2015      3.95
# 13609      PEN  Retail      KG         3     2015      3.95
# 13610      PEN  Retail      KG         4     2015      3.95
# 13611      PEN  Retail      KG         5     2015      3.95
# 13612      PEN  Retail      KG         6     2015      3.96
# 13613      PEN  Retail      KG         7     2015      3.97
# 13614      PEN  Retail      KG         8     2015      3.97
# 13615      PEN  Retail      KG         9     2015      3.98
# 13616      PEN  Retail      KG        10     2015      3.98
# 13617      PEN  Retail      KG        11     2015      4.01
# 13618      PEN  Retail      KG        12     2015      4.03
# 13619      PEN  Retail      KG         1     2016      4.07
# 13620      PEN  Retail      KG         2     2016      4.09
# 13621      PEN  Retail      KG         3     2016      4.10
# 13622      PEN  Retail      KG         4     2016      4.11
# 13623      PEN  Retail      KG         5     2016      4.14
# 13624      PEN  Retail      KG         6     2016      4.17
# 13625      PEN  Retail      KG         7     2016      4.20
#
#                                       mp_commoditysource
# 0                                                    INE
# 1                                                    INE
# 2                                                    INE
# 3                                                    INE
# 4                                                    INE
# 5                                                    INE
# 6                                                    INE
# 7                                                    INE
# 8                                                    INE
# 9                                                    INE
# 10                                                   INE
# 11                                                   INE
# 12                                                   INE
# 13                                                   INE
# 14                                                   INE
# 15                                                   INE
# 16                                                   INE
# 17                                                   INE
# 18                                                   INE
# 19                                                   INE
# 20                                                   INE
# 21                                                   INE
# 22                                                   INE
# 23                                                   INE
# 24                                                   INE
# 25                                                   INE
# 26                                                   INE
# 27                                                   INE
# 28                                                   INE
# 29                                                   INE
# ...                                                  ...
# 13596                                               INEI
# 13597                                               INEI
# 13598                                               INEI
# 13599                                               INEI
# 13600                                               INEI
# 13601                                               INEI
# 13602                                               INEI
# 13603                                               INEI
# 13604                                               INEI
# 13605                                               INEI
# 13606  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13607  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13608  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13609  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13610  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13611  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13612  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13613  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13614  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13615  INEI (http://iinei.inei.gob.pe/iinei/siemweb/p...
# 13616    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13617    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13618    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13619    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13620    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13621    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13622    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13623    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13624    http://iinei.inei.gob.pe/iinei/siemweb/publico/
# 13625    http://iinei.inei.gob.pe/iinei/siemweb/publico/
#
# [13626 rows x 11 columns]

# %% [markdown]
# Saving files to R:

# %%
Price.to_csv("Price.csv",index=None)
