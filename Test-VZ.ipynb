# %%
print('hello world')

# %% [markdown]
# ### Datasets:
#
# Here's one dataset for food prices https://www.kaggle.com/jboysen/global-food-prices
#
# Here is the dataset for temperature and rainfalls http://sdwebx.worldbank.org/climateportal/index.cfm?page=downscaled_data_download&menu=historical

# %% [markdown]
# ### Hypothesis:
#
# Do changes in average temperature and average level of rainfall affect the change in the average price on X crop in X country in X-X years

# %% [markdown]
# ### Questions to the Professor:
#
# 1. How can we all access and work simultaneously in the shared Github repo (with 1 master and 3 collaborators)?

# %%
import pandas as pd

pricesdata='https://raw.githubusercontent.com/vzakhozhyi/599-A-Final-Project/master/Data/wfp_market_food_prices.csv'
prices = pd.read_csv(pricesdata,header=0, encoding = 'ISO-8859-1')

#Bolivia
TBdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Temp_Bolivia.xls"
TB=pd.read_excel(TBdata)

RFBdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Rainfall_Bolivia.xls"
RFB=pd.read_excel(RFBdata)

#Peru
TPdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Temp_Peru.xls"
TP=pd.read_excel(TPdata)

RFPdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Rainfall_Peru.xls"
RFP=pd.read_excel(RFPdata)

#Colombia
TCdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Temp_Colombia.xls"
TC=pd.read_excel(TCdata)

RFCdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Rainfall_Colombia.xls"
RFC=pd.read_excel(RFCdata)

# %%
prices.shape
prices.head(10)
prices.tail(10)
# Out:
# (743914, 18)

# %%
# Out:
#         adm0_id    adm0_name  adm1_id          adm1_name  mkt_id mkt_name  \
# 743904    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743905    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743906    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743907    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743908    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743909    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743910    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743911    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743912    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743913    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
#
#         cm_id                 cm_name  cur_id cur_name  pt_id pt_name  um_id  \
# 743904    156                  Sesame      83      SSP     15  Retail     47
# 743905    156                  Sesame      83      SSP     15  Retail     47
# 743906    156                  Sesame      83      SSP     15  Retail     47
# 743907    156                  Sesame      83      SSP     15  Retail     47
# 743908    156                  Sesame      83      SSP     15  Retail     47
# 743909    156                  Sesame      83      SSP     15  Retail     47
# 743910    284           Fuel (diesel)      83      SSP     15  Retail     15
# 743911    284           Fuel (diesel)      83      SSP     15  Retail     15
# 743912    285  Fuel (petrol-gasoline)      83      SSP     15  Retail     15
# 743913    285  Fuel (petrol-gasoline)      83      SSP     15  Retail     15
#
#        um_name  mp_month  mp_year  mp_price mp_commoditysource
# 743904  3.5 KG         5     2016     115.0                WFP
# 743905  3.5 KG         7     2016     100.0                WFP
# 743906  3.5 KG         2     2017     425.0                WFP
# 743907  3.5 KG         3     2017     443.0                WFP
# 743908  3.5 KG         4     2017     425.0                WFP
# 743909  3.5 KG         5     2017     400.0                WFP
# 743910       L         2     2017      12.5                WFP
# 743911       L         3     2017      95.0                WFP
# 743912       L         2     2017      95.0                WFP
# 743913       L         3     2017      93.7                WFP

# %%
prices.dtypes
# Out:
# adm0_id                 int64
# adm0_name              object
# adm1_id                 int64
# adm1_name              object
# mkt_id                  int64
# mkt_name               object
# cm_id                   int64
# cm_name                object
# cur_id                  int64
# cur_name               object
# pt_id                   int64
# pt_name                object
# um_id                   int64
# um_name                object
# mp_month                int64
# mp_year                 int64
# mp_price              float64
# mp_commoditysource     object
# dtype: object

# %%
prices.adm0_name.unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Armenia', 'Azerbaijan', 'Bangladesh',
#        'Benin', 'Bhutan', 'Bolivia', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Cape Verde', 'Central African Republic',
#        'Chad', 'Colombia', 'Congo', 'Costa Rica', "Cote d'Ivoire",
#        'Democratic Republic of the Congo', 'Djibouti', 'El Salvador',
#        'Ethiopia', 'Gambia', 'Georgia', 'Ghana', 'Guatemala',
#        'Guinea-Bissau', 'Guinea', 'Haiti', 'Honduras', 'India',
#        'Indonesia', 'Iran  (Islamic Republic of)', 'Iraq', 'Jordan',
#        'Kenya', 'Kyrgyzstan', "Lao People's Democratic Republic",
#        'Lebanon', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Mozambique', 'Myanmar', 'Nepal', 'Niger', 'Nigeria',
#        'Pakistan', 'Panama', 'Peru', 'Philippines', 'Rwanda', 'Senegal',
#        'Somalia', 'Sri Lanka', 'Swaziland', 'Syrian Arab Republic',
#        'Tajikistan', 'Timor-Leste', 'Turkey', 'Uganda', 'Ukraine',
#        'United Republic of Tanzania', 'Yemen', 'Zambia', 'Zimbabwe',
#        'State of Palestine', 'Sudan', 'Egypt', 'South Sudan'],
#       dtype=object)

# %%
TargetCountry = ['Bolivia', "Peru", 'Colombia']
TargetCrop = ["Potatoes"]

# %%
prices[(prices.adm0_name=='Bolivia')].cm_name.unique()
# Out:
# array(['Eggs', 'Sugar', 'Meat (beef, chops with bones)',
#        'Meat (chicken, whole)', 'Noodles (short)', 'Potatoes (Dutch)',
#        'Potatoes (Irish, imilla)', 'Rice (estaquilla)',
#        'Rice (long grain)', 'Bread (wheat)', 'Rice (good quality)',
#        'Rice (white)', 'Rice (carolina 2da)', 'Rice (medium grain)',
#        'Potatoes (black)'], dtype=object)

# %%
prices[(prices.adm0_name=='Peru')].cm_name.unique()
# Out:
# array(['Maize (local)', 'Rice (local)', 'Potatoes', 'Meat (chicken)',
#        'Oil (vegetable)', 'Sugar', 'Wheat flour (locally processed)'],
#       dtype=object)

# %%
prices[(prices.adm0_name=='Colombia')].cm_name.unique()
# Out:
# array(['Wheat flour', 'Maize (white)', 'Maize flour', 'Beans (red)',
#        'Potatoes', 'Meat (chicken)', 'Oil (vegetable)', 'Sugar', 'Garlic',
#        'Onions (red)', 'Onions (white)', 'Pasta', 'Tomatoes',
#        'Rice (white)', 'Maize (yellow)', 'Meat (beef)', 'Plantains',
#        'Cocoa', 'Coffee', 'Carrots', 'Fish (dry)', 'Cabbage', 'Salt',
#        'Rice (paddy)', 'Chickpeas (imported)', 'Eggs (white, AA)',
#        'Meat (beef, minced)', 'Peas (green, dry)', 'Potatoes (unica)',
#        'Sugar (brown)', 'Sugar (brown, loaf)', 'Apples (red)',
#        'Cauliflower', 'Cucumbers (greenhouse)', 'Oranges (big size)',
#        'Bananas', 'Beans (red, fresh)', 'Fuel (diesel)',
#        'Fuel (petrol-gasoline)', 'Cassava (dry)', 'Spinach',
#        'Fish (tilapia)', 'Beans (string)', 'Guava', 'Papaya',
#        'Blackberry', 'Broccoli', 'Mangoes', 'Pumpkin',
#        'Tamarillos/tree tomatoes', 'Cheese', 'Lentils (imported)',
#        'Milk (pasteurized)',
#        'Wage (non-qualified labour, non-agricultural)', 'Meat (pork)',
#        'Coffee (instant)', 'Oil (sunflower)'], dtype=object)

# %%
# This is what you want get rid of:
ColumnsToDrop = ['adm0_id', 'adm1_id','mkt_id','cm_id','cur_id','pt_id','um_id']#,'mp_commoditysource']

#this would change the original: GhanaYamPrice.drop(byeColumns,axis=1,inplace=False)
prices=prices.drop(ColumnsToDrop,axis=1, inplace=False).reset_index(drop=True)

# %%
prices
# Out:
#           adm0_name          adm1_name  mkt_name                 cm_name  \
# 0       Afghanistan         Badakhshan  Fayzabad                   Bread
# 1       Afghanistan         Badakhshan  Fayzabad                   Bread
# 2       Afghanistan         Badakhshan  Fayzabad                   Bread
# 3       Afghanistan         Badakhshan  Fayzabad                   Bread
# 4       Afghanistan         Badakhshan  Fayzabad                   Bread
# 5       Afghanistan         Badakhshan  Fayzabad                   Bread
# 6       Afghanistan         Badakhshan  Fayzabad                   Bread
# 7       Afghanistan         Badakhshan  Fayzabad                   Bread
# 8       Afghanistan         Badakhshan  Fayzabad                   Bread
# 9       Afghanistan         Badakhshan  Fayzabad                   Bread
# 10      Afghanistan         Badakhshan  Fayzabad                   Bread
# 11      Afghanistan         Badakhshan  Fayzabad                   Bread
# 12      Afghanistan         Badakhshan  Fayzabad                   Bread
# 13      Afghanistan         Badakhshan  Fayzabad                   Bread
# 14      Afghanistan         Badakhshan  Fayzabad                   Bread
# 15      Afghanistan         Badakhshan  Fayzabad                   Bread
# 16      Afghanistan         Badakhshan  Fayzabad                   Bread
# 17      Afghanistan         Badakhshan  Fayzabad                   Bread
# 18      Afghanistan         Badakhshan  Fayzabad                   Bread
# 19      Afghanistan         Badakhshan  Fayzabad                   Bread
# 20      Afghanistan         Badakhshan  Fayzabad                   Bread
# 21      Afghanistan         Badakhshan  Fayzabad                   Bread
# 22      Afghanistan         Badakhshan  Fayzabad                   Bread
# 23      Afghanistan         Badakhshan  Fayzabad                   Bread
# 24      Afghanistan         Badakhshan  Fayzabad                   Bread
# 25      Afghanistan         Badakhshan  Fayzabad                   Bread
# 26      Afghanistan         Badakhshan  Fayzabad                   Bread
# 27      Afghanistan         Badakhshan  Fayzabad                   Bread
# 28      Afghanistan         Badakhshan  Fayzabad                   Bread
# 29      Afghanistan         Badakhshan  Fayzabad                   Bread
# ...             ...                ...       ...                     ...
# 743884  South Sudan  Eastern Equatoria     Torit         Sorghum (white)
# 743885  South Sudan  Eastern Equatoria     Torit         Sorghum (white)
# 743886  South Sudan  Eastern Equatoria     Torit         Sorghum (white)
# 743887  South Sudan  Eastern Equatoria     Torit          Millet (white)
# 743888  South Sudan  Eastern Equatoria     Torit          Millet (white)
# 743889  South Sudan  Eastern Equatoria     Torit          Millet (white)
# 743890  South Sudan  Eastern Equatoria     Torit          Millet (white)
# 743891  South Sudan  Eastern Equatoria     Torit          Millet (white)
# 743892  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743893  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743894  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743895  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743896  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743897  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743898  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743899  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743900  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743901  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743902  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743903  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743904  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743905  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743906  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743907  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743908  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743909  South Sudan  Eastern Equatoria     Torit                  Sesame
# 743910  South Sudan  Eastern Equatoria     Torit           Fuel (diesel)
# 743911  South Sudan  Eastern Equatoria     Torit           Fuel (diesel)
# 743912  South Sudan  Eastern Equatoria     Torit  Fuel (petrol-gasoline)
# 743913  South Sudan  Eastern Equatoria     Torit  Fuel (petrol-gasoline)
#
#        cur_name pt_name um_name  mp_month  mp_year  mp_price  \
# 0           AFN  Retail      KG         1     2014     50.00
# 1           AFN  Retail      KG         2     2014     50.00
# 2           AFN  Retail      KG         3     2014     50.00
# 3           AFN  Retail      KG         4     2014     50.00
# 4           AFN  Retail      KG         5     2014     50.00
# 5           AFN  Retail      KG         6     2014     50.00
# 6           AFN  Retail      KG         7     2014     50.00
# 7           AFN  Retail      KG         8     2014     50.00
# 8           AFN  Retail      KG         9     2014     50.00
# 9           AFN  Retail      KG        10     2014     50.00
# 10          AFN  Retail      KG        11     2014     50.00
# 11          AFN  Retail      KG        12     2014     50.00
# 12          AFN  Retail      KG         1     2015     50.00
# 13          AFN  Retail      KG         2     2015     50.00
# 14          AFN  Retail      KG         3     2015     50.00
# 15          AFN  Retail      KG         6     2015     50.00
# 16          AFN  Retail      KG         7     2015     50.00
# 17          AFN  Retail      KG         8     2015     50.00
# 18          AFN  Retail      KG         9     2015     50.00
# 19          AFN  Retail      KG        10     2015     56.25
# 20          AFN  Retail      KG        11     2015     65.25
# 21          AFN  Retail      KG        12     2015     55.50
# 22          AFN  Retail      KG         1     2016     55.50
# 23          AFN  Retail      KG         2     2016     55.50
# 24          AFN  Retail      KG         3     2016     55.50
# 25          AFN  Retail      KG         4     2016     50.00
# 26          AFN  Retail      KG         5     2016     50.00
# 27          AFN  Retail      KG         6     2016     50.00
# 28          AFN  Retail      KG         7     2016     50.00
# 29          AFN  Retail      KG         8     2016     50.00
# ...         ...     ...     ...       ...      ...       ...
# 743884      SSP  Retail  3.5 KG         8     2016     10.00
# 743885      SSP  Retail  3.5 KG         4     2017    286.50
# 743886      SSP  Retail  3.5 KG         5     2017    360.00
# 743887      SSP  Retail  3.5 KG         8     2014     16.75
# 743888      SSP  Retail  3.5 KG         9     2014     16.00
# 743889      SSP  Retail  3.5 KG        10     2014     15.50
# 743890      SSP  Retail  3.5 KG         3     2016     57.50
# 743891      SSP  Retail  3.5 KG         7     2016     63.50
# 743892      SSP  Retail  3.5 KG         8     2014     37.50
# 743893      SSP  Retail  3.5 KG         9     2014     35.00
# 743894      SSP  Retail  3.5 KG        10     2014     37.50
# 743895      SSP  Retail  3.5 KG        11     2014     40.00
# 743896      SSP  Retail  3.5 KG        12     2014     19.50
# 743897      SSP  Retail  3.5 KG         1     2015     33.00
# 743898      SSP  Retail  3.5 KG         2     2015     31.00
# 743899      SSP  Retail  3.5 KG         3     2015     25.00
# 743900      SSP  Retail  3.5 KG         4     2015     33.00
# 743901      SSP  Retail  3.5 KG         1     2016     90.00
# 743902      SSP  Retail  3.5 KG         3     2016    100.00
# 743903      SSP  Retail  3.5 KG         4     2016    121.00
# 743904      SSP  Retail  3.5 KG         5     2016    115.00
# 743905      SSP  Retail  3.5 KG         7     2016    100.00
# 743906      SSP  Retail  3.5 KG         2     2017    425.00
# 743907      SSP  Retail  3.5 KG         3     2017    443.00
# 743908      SSP  Retail  3.5 KG         4     2017    425.00
# 743909      SSP  Retail  3.5 KG         5     2017    400.00
# 743910      SSP  Retail       L         2     2017     12.50
# 743911      SSP  Retail       L         3     2017     95.00
# 743912      SSP  Retail       L         2     2017     95.00
# 743913      SSP  Retail       L         3     2017     93.70
#
#        mp_commoditysource
# 0                     WFP
# 1                     WFP
# 2                     WFP
# 3                     WFP
# 4                     WFP
# 5                     WFP
# 6                     WFP
# 7                     WFP
# 8                     WFP
# 9                     WFP
# 10                    WFP
# 11                    WFP
# 12                    WFP
# 13                    WFP
# 14                    WFP
# 15                    WFP
# 16                    WFP
# 17                    WFP
# 18                    WFP
# 19                    WFP
# 20                    WFP
# 21                    WFP
# 22                    WFP
# 23                    WFP
# 24                    WFP
# 25                    WFP
# 26                    WFP
# 27                    WFP
# 28                    WFP
# 29                    WFP
# ...                   ...
# 743884                WFP
# 743885                WFP
# 743886                WFP
# 743887                WFP
# 743888                WFP
# 743889                WFP
# 743890                WFP
# 743891                WFP
# 743892                WFP
# 743893                WFP
# 743894                WFP
# 743895                WFP
# 743896                WFP
# 743897                WFP
# 743898                WFP
# 743899                WFP
# 743900                WFP
# 743901                WFP
# 743902                WFP
# 743903                WFP
# 743904                WFP
# 743905                WFP
# 743906                WFP
# 743907                WFP
# 743908                WFP
# 743909                WFP
# 743910                WFP
# 743911                WFP
# 743912                WFP
# 743913                WFP
#
# [743914 rows x 11 columns]

# %% [markdown]
# RF and Temp

# %%
RFdataframes = [RFB, RFC, RFP]
RFdataframes
# Out:
# [            pr  \tYear   Month  Country   ISO3   ISO2
#  0    209.90400    1991       1      BOL    NaN    NaN
#  1    165.21000    1991       2      BOL    NaN    NaN
#  2    166.84700    1991       3      BOL    NaN    NaN
#  3     85.99840    1991       4      BOL    NaN    NaN
#  4     49.60090    1991       5      BOL    NaN    NaN
#  5     47.32130    1991       6      BOL    NaN    NaN
#  6     19.88850    1991       7      BOL    NaN    NaN
#  7      8.16148    1991       8      BOL    NaN    NaN
#  8     47.95680    1991       9      BOL    NaN    NaN
#  9     79.60350    1991      10      BOL    NaN    NaN
#  10   114.01300    1991      11      BOL    NaN    NaN
#  11   111.58800    1991      12      BOL    NaN    NaN
#  12   186.88300    1992       1      BOL    NaN    NaN
#  13   131.20400    1992       2      BOL    NaN    NaN
#  14   155.87000    1992       3      BOL    NaN    NaN
#  15    88.35530    1992       4      BOL    NaN    NaN
#  16    58.82030    1992       5      BOL    NaN    NaN
#  17    46.41200    1992       6      BOL    NaN    NaN
#  18    27.76540    1992       7      BOL    NaN    NaN
#  19    61.41150    1992       8      BOL    NaN    NaN
#  20    60.20360    1992       9      BOL    NaN    NaN
#  21   109.50100    1992      10      BOL    NaN    NaN
#  22   129.31800    1992      11      BOL    NaN    NaN
#  23   123.69000    1992      12      BOL    NaN    NaN
#  24   243.79900    1993       1      BOL    NaN    NaN
#  25   111.17500    1993       2      BOL    NaN    NaN
#  26   147.96800    1993       3      BOL    NaN    NaN
#  27    64.30880    1993       4      BOL    NaN    NaN
#  28    28.93670    1993       5      BOL    NaN    NaN
#  29    14.50230    1993       6      BOL    NaN    NaN
#  ..         ...     ...     ...      ...    ...    ...
#  270    8.10500    2013       7      BOL    NaN    NaN
#  271   25.65330    2013       8      BOL    NaN    NaN
#  272   43.11240    2013       9      BOL    NaN    NaN
#  273  115.41200    2013      10      BOL    NaN    NaN
#  274  124.43400    2013      11      BOL    NaN    NaN
#  275  176.86500    2013      12      BOL    NaN    NaN
#  276  258.94700    2014       1      BOL    NaN    NaN
#  277  212.88200    2014       2      BOL    NaN    NaN
#  278  193.64600    2014       3      BOL    NaN    NaN
#  279   74.63690    2014       4      BOL    NaN    NaN
#  280   63.21620    2014       5      BOL    NaN    NaN
#  281   27.83580    2014       6      BOL    NaN    NaN
#  282   27.27870    2014       7      BOL    NaN    NaN
#  283   15.81190    2014       8      BOL    NaN    NaN
#  284   48.35210    2014       9      BOL    NaN    NaN
#  285   40.61980    2014      10      BOL    NaN    NaN
#  286  111.40900    2014      11      BOL    NaN    NaN
#  287   87.43710    2014      12      BOL    NaN    NaN
#  288  188.35200    2015       1      BOL    NaN    NaN
#  289  191.45700    2015       2      BOL    NaN    NaN
#  290  142.02900    2015       3      BOL    NaN    NaN
#  291  112.32200    2015       4      BOL    NaN    NaN
#  292  103.16100    2015       5      BOL    NaN    NaN
#  293   28.89860    2015       6      BOL    NaN    NaN
#  294   58.26810    2015       7      BOL    NaN    NaN
#  295   20.43510    2015       8      BOL    NaN    NaN
#  296   43.78800    2015       9      BOL    NaN    NaN
#  297   54.58650    2015      10      BOL    NaN    NaN
#  298   89.38320    2015      11      BOL    NaN    NaN
#  299   88.48570    2015      12      BOL    NaN    NaN
#
#  [300 rows x 6 columns],            pr  \tYear   Month  Country   ISO3   ISO2
#  0     56.1426    1991       1      COL    NaN    NaN
#  1     83.2545    1991       2      COL    NaN    NaN
#  2    220.2360    1991       3      COL    NaN    NaN
#  3    209.4310    1991       4      COL    NaN    NaN
#  4    234.1020    1991       5      COL    NaN    NaN
#  5    238.5100    1991       6      COL    NaN    NaN
#  6    223.8870    1991       7      COL    NaN    NaN
#  7    200.3270    1991       8      COL    NaN    NaN
#  8    188.0760    1991       9      COL    NaN    NaN
#  9    150.8850    1991      10      COL    NaN    NaN
#  10   188.0560    1991      11      COL    NaN    NaN
#  11    93.5771    1991      12      COL    NaN    NaN
#  12    59.9233    1992       1      COL    NaN    NaN
#  13    86.4726    1992       2      COL    NaN    NaN
#  14   113.8630    1992       3      COL    NaN    NaN
#  15   202.7130    1992       4      COL    NaN    NaN
#  16   223.4910    1992       5      COL    NaN    NaN
#  17   204.4660    1992       6      COL    NaN    NaN
#  18   235.4130    1992       7      COL    NaN    NaN
#  19   235.4210    1992       8      COL    NaN    NaN
#  20   222.8440    1992       9      COL    NaN    NaN
#  21   156.2300    1992      10      COL    NaN    NaN
#  22   182.0250    1992      11      COL    NaN    NaN
#  23   148.5850    1992      12      COL    NaN    NaN
#  24   146.5230    1993       1      COL    NaN    NaN
#  25   119.3580    1993       2      COL    NaN    NaN
#  26   213.0440    1993       3      COL    NaN    NaN
#  27   268.1350    1993       4      COL    NaN    NaN
#  28   289.3320    1993       5      COL    NaN    NaN
#  29   194.5360    1993       6      COL    NaN    NaN
#  ..        ...     ...     ...      ...    ...    ...
#  270  149.0250    2013       7      COL    NaN    NaN
#  271  309.0680    2013       8      COL    NaN    NaN
#  272  220.7070    2013       9      COL    NaN    NaN
#  273  176.3320    2013      10      COL    NaN    NaN
#  274  192.6870    2013      11      COL    NaN    NaN
#  275  113.8580    2013      12      COL    NaN    NaN
#  276   89.1602    2014       1      COL    NaN    NaN
#  277  111.7820    2014       2      COL    NaN    NaN
#  278  149.6340    2014       3      COL    NaN    NaN
#  279  183.5800    2014       4      COL    NaN    NaN
#  280  233.4160    2014       5      COL    NaN    NaN
#  281  215.4540    2014       6      COL    NaN    NaN
#  282  219.8450    2014       7      COL    NaN    NaN
#  283  252.3560    2014       8      COL    NaN    NaN
#  284  188.1280    2014       9      COL    NaN    NaN
#  285  230.3030    2014      10      COL    NaN    NaN
#  286  238.2620    2014      11      COL    NaN    NaN
#  287  181.0480    2014      12      COL    NaN    NaN
#  288  148.6860    2015       1      COL    NaN    NaN
#  289  105.0790    2015       2      COL    NaN    NaN
#  290  266.6620    2015       3      COL    NaN    NaN
#  291  228.5930    2015       4      COL    NaN    NaN
#  292  200.8960    2015       5      COL    NaN    NaN
#  293  264.8430    2015       6      COL    NaN    NaN
#  294  259.0020    2015       7      COL    NaN    NaN
#  295  189.6000    2015       8      COL    NaN    NaN
#  296  138.0360    2015       9      COL    NaN    NaN
#  297  157.3480    2015      10      COL    NaN    NaN
#  298  173.8600    2015      11      COL    NaN    NaN
#  299   96.3039    2015      12      COL    NaN    NaN
#
#  [300 rows x 6 columns],            pr  \tYear   Month  Country   ISO3   ISO2
#  0    110.7720    1991       1      PER    NaN    NaN
#  1    149.8710    1991       2      PER    NaN    NaN
#  2    180.9780    1991       3      PER    NaN    NaN
#  3    113.0370    1991       4      PER    NaN    NaN
#  4    122.3220    1991       5      PER    NaN    NaN
#  5    104.7460    1991       6      PER    NaN    NaN
#  6     35.2588    1991       7      PER    NaN    NaN
#  7     51.8483    1991       8      PER    NaN    NaN
#  8     88.4582    1991       9      PER    NaN    NaN
#  9     98.1672    1991      10      PER    NaN    NaN
#  10   142.3550    1991      11      PER    NaN    NaN
#  11   103.6000    1991      12      PER    NaN    NaN
#  12   108.7610    1992       1      PER    NaN    NaN
#  13   128.3800    1992       2      PER    NaN    NaN
#  14   157.7920    1992       3      PER    NaN    NaN
#  15   112.8990    1992       4      PER    NaN    NaN
#  16    55.7750    1992       5      PER    NaN    NaN
#  17    57.1915    1992       6      PER    NaN    NaN
#  18    68.9449    1992       7      PER    NaN    NaN
#  19   106.4590    1992       8      PER    NaN    NaN
#  20   125.3000    1992       9      PER    NaN    NaN
#  21   103.7470    1992      10      PER    NaN    NaN
#  22   129.0480    1992      11      PER    NaN    NaN
#  23   155.4120    1992      12      PER    NaN    NaN
#  24   255.5960    1993       1      PER    NaN    NaN
#  25   143.0690    1993       2      PER    NaN    NaN
#  26   208.5180    1993       3      PER    NaN    NaN
#  27   184.8360    1993       4      PER    NaN    NaN
#  28   103.7290    1993       5      PER    NaN    NaN
#  29    59.8479    1993       6      PER    NaN    NaN
#  ..        ...     ...     ...      ...    ...    ...
#  270   75.5839    2013       7      PER    NaN    NaN
#  271   78.4017    2013       8      PER    NaN    NaN
#  272   74.5302    2013       9      PER    NaN    NaN
#  273  145.3160    2013      10      PER    NaN    NaN
#  274  143.2180    2013      11      PER    NaN    NaN
#  275  152.0900    2013      12      PER    NaN    NaN
#  276  159.0640    2014       1      PER    NaN    NaN
#  277  149.2600    2014       2      PER    NaN    NaN
#  278  193.8480    2014       3      PER    NaN    NaN
#  279  172.6720    2014       4      PER    NaN    NaN
#  280   91.7503    2014       5      PER    NaN    NaN
#  281   74.1397    2014       6      PER    NaN    NaN
#  282   71.6753    2014       7      PER    NaN    NaN
#  283   77.6913    2014       8      PER    NaN    NaN
#  284   83.2653    2014       9      PER    NaN    NaN
#  285  108.8530    2014      10      PER    NaN    NaN
#  286  127.2600    2014      11      PER    NaN    NaN
#  287  174.0690    2014      12      PER    NaN    NaN
#  288  154.3840    2015       1      PER    NaN    NaN
#  289  182.3060    2015       2      PER    NaN    NaN
#  290  187.5390    2015       3      PER    NaN    NaN
#  291  179.8370    2015       4      PER    NaN    NaN
#  292  109.1790    2015       5      PER    NaN    NaN
#  293   68.5707    2015       6      PER    NaN    NaN
#  294  102.3850    2015       7      PER    NaN    NaN
#  295   58.2170    2015       8      PER    NaN    NaN
#  296   57.6487    2015       9      PER    NaN    NaN
#  297   64.1029    2015      10      PER    NaN    NaN
#  298   99.1171    2015      11      PER    NaN    NaN
#  299  151.3360    2015      12      PER    NaN    NaN
#
#  [300 rows x 6 columns]]

# %%
RF = pd.concat(RFdataframes)
RF
# Out:
#             pr  \tYear   Month  Country   ISO3   ISO2
# 0    209.90400    1991       1      BOL    NaN    NaN
# 1    165.21000    1991       2      BOL    NaN    NaN
# 2    166.84700    1991       3      BOL    NaN    NaN
# 3     85.99840    1991       4      BOL    NaN    NaN
# 4     49.60090    1991       5      BOL    NaN    NaN
# 5     47.32130    1991       6      BOL    NaN    NaN
# 6     19.88850    1991       7      BOL    NaN    NaN
# 7      8.16148    1991       8      BOL    NaN    NaN
# 8     47.95680    1991       9      BOL    NaN    NaN
# 9     79.60350    1991      10      BOL    NaN    NaN
# 10   114.01300    1991      11      BOL    NaN    NaN
# 11   111.58800    1991      12      BOL    NaN    NaN
# 12   186.88300    1992       1      BOL    NaN    NaN
# 13   131.20400    1992       2      BOL    NaN    NaN
# 14   155.87000    1992       3      BOL    NaN    NaN
# 15    88.35530    1992       4      BOL    NaN    NaN
# 16    58.82030    1992       5      BOL    NaN    NaN
# 17    46.41200    1992       6      BOL    NaN    NaN
# 18    27.76540    1992       7      BOL    NaN    NaN
# 19    61.41150    1992       8      BOL    NaN    NaN
# 20    60.20360    1992       9      BOL    NaN    NaN
# 21   109.50100    1992      10      BOL    NaN    NaN
# 22   129.31800    1992      11      BOL    NaN    NaN
# 23   123.69000    1992      12      BOL    NaN    NaN
# 24   243.79900    1993       1      BOL    NaN    NaN
# 25   111.17500    1993       2      BOL    NaN    NaN
# 26   147.96800    1993       3      BOL    NaN    NaN
# 27    64.30880    1993       4      BOL    NaN    NaN
# 28    28.93670    1993       5      BOL    NaN    NaN
# 29    14.50230    1993       6      BOL    NaN    NaN
# ..         ...     ...     ...      ...    ...    ...
# 270   75.58390    2013       7      PER    NaN    NaN
# 271   78.40170    2013       8      PER    NaN    NaN
# 272   74.53020    2013       9      PER    NaN    NaN
# 273  145.31600    2013      10      PER    NaN    NaN
# 274  143.21800    2013      11      PER    NaN    NaN
# 275  152.09000    2013      12      PER    NaN    NaN
# 276  159.06400    2014       1      PER    NaN    NaN
# 277  149.26000    2014       2      PER    NaN    NaN
# 278  193.84800    2014       3      PER    NaN    NaN
# 279  172.67200    2014       4      PER    NaN    NaN
# 280   91.75030    2014       5      PER    NaN    NaN
# 281   74.13970    2014       6      PER    NaN    NaN
# 282   71.67530    2014       7      PER    NaN    NaN
# 283   77.69130    2014       8      PER    NaN    NaN
# 284   83.26530    2014       9      PER    NaN    NaN
# 285  108.85300    2014      10      PER    NaN    NaN
# 286  127.26000    2014      11      PER    NaN    NaN
# 287  174.06900    2014      12      PER    NaN    NaN
# 288  154.38400    2015       1      PER    NaN    NaN
# 289  182.30600    2015       2      PER    NaN    NaN
# 290  187.53900    2015       3      PER    NaN    NaN
# 291  179.83700    2015       4      PER    NaN    NaN
# 292  109.17900    2015       5      PER    NaN    NaN
# 293   68.57070    2015       6      PER    NaN    NaN
# 294  102.38500    2015       7      PER    NaN    NaN
# 295   58.21700    2015       8      PER    NaN    NaN
# 296   57.64870    2015       9      PER    NaN    NaN
# 297   64.10290    2015      10      PER    NaN    NaN
# 298   99.11710    2015      11      PER    NaN    NaN
# 299  151.33600    2015      12      PER    NaN    NaN
#
# [900 rows x 6 columns]

# %%
RFclean=RF.drop(columns=[' ISO3', ' ISO2'])

# %%
RFclean.columns
# Out:
# Index(['pr', '\tYear', ' Month', ' Country'], dtype='object')

# %%
newnames=['rainfall', 'year', ' month', 'country']
newRFnames={old:new for old,new in zip(RFclean,newnames)}
RFclean.rename(columns=newRFnames,inplace=True)
RFclean
# Out:
#       rainfall  year   month  country
# 204  263.36900  2008       1  Bolivia
# 205  172.84400  2008       2  Bolivia
# 206  149.58100  2008       3  Bolivia
# 207   76.82790  2008       4  Bolivia
# 208   30.45810  2008       5  Bolivia
# 209   13.34890  2008       6  Bolivia
# 210   14.34370  2008       7  Bolivia
# 211   24.58480  2008       8  Bolivia
# 212   29.27220  2008       9  Bolivia
# 213   87.85920  2008      10  Bolivia
# 214   98.86760  2008      11  Bolivia
# 215  145.82900  2008      12  Bolivia
# 216  141.14800  2009       1  Bolivia
# 217  206.48200  2009       2  Bolivia
# 218  209.90700  2009       3  Bolivia
# 219  118.54100  2009       4  Bolivia
# 220   39.35400  2009       5  Bolivia
# 221   24.84850  2009       6  Bolivia
# 222   51.58120  2009       7  Bolivia
# 223   26.70180  2009       8  Bolivia
# 224   39.98530  2009       9  Bolivia
# 225   64.76110  2009      10  Bolivia
# 226  102.22700  2009      11  Bolivia
# 227  173.78800  2009      12  Bolivia
# 228  208.90700  2010       1  Bolivia
# 229  183.61100  2010       2  Bolivia
# 230  145.20200  2010       3  Bolivia
# 231   37.84850  2010       4  Bolivia
# 232   58.89930  2010       5  Bolivia
# 233    7.69902  2010       6  Bolivia
# ..         ...   ...     ...      ...
# 270   75.58390  2013       7     Peru
# 271   78.40170  2013       8     Peru
# 272   74.53020  2013       9     Peru
# 273  145.31600  2013      10     Peru
# 274  143.21800  2013      11     Peru
# 275  152.09000  2013      12     Peru
# 276  159.06400  2014       1     Peru
# 277  149.26000  2014       2     Peru
# 278  193.84800  2014       3     Peru
# 279  172.67200  2014       4     Peru
# 280   91.75030  2014       5     Peru
# 281   74.13970  2014       6     Peru
# 282   71.67530  2014       7     Peru
# 283   77.69130  2014       8     Peru
# 284   83.26530  2014       9     Peru
# 285  108.85300  2014      10     Peru
# 286  127.26000  2014      11     Peru
# 287  174.06900  2014      12     Peru
# 288  154.38400  2015       1     Peru
# 289  182.30600  2015       2     Peru
# 290  187.53900  2015       3     Peru
# 291  179.83700  2015       4     Peru
# 292  109.17900  2015       5     Peru
# 293   68.57070  2015       6     Peru
# 294  102.38500  2015       7     Peru
# 295   58.21700  2015       8     Peru
# 296   57.64870  2015       9     Peru
# 297   64.10290  2015      10     Peru
# 298   99.11710  2015      11     Peru
# 299  151.33600  2015      12     Peru
#
# [288 rows x 4 columns]

# %%
RFclean['country']=RFclean['country'].replace(['PER'], 'Peru')
RFclean['country']=RFclean['country'].replace(['COL'], 'Columbia')
RFclean['country']=RFclean['country'].replace(['BOL'], 'Bolivia')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
Years = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
RFclean = RFclean[RFclean.year.isin(Years)]
RFclean
# Out:
#       rainfall  year   month  country
# 204  263.36900  2008       1  Bolivia
# 205  172.84400  2008       2  Bolivia
# 206  149.58100  2008       3  Bolivia
# 207   76.82790  2008       4  Bolivia
# 208   30.45810  2008       5  Bolivia
# 209   13.34890  2008       6  Bolivia
# 210   14.34370  2008       7  Bolivia
# 211   24.58480  2008       8  Bolivia
# 212   29.27220  2008       9  Bolivia
# 213   87.85920  2008      10  Bolivia
# 214   98.86760  2008      11  Bolivia
# 215  145.82900  2008      12  Bolivia
# 216  141.14800  2009       1  Bolivia
# 217  206.48200  2009       2  Bolivia
# 218  209.90700  2009       3  Bolivia
# 219  118.54100  2009       4  Bolivia
# 220   39.35400  2009       5  Bolivia
# 221   24.84850  2009       6  Bolivia
# 222   51.58120  2009       7  Bolivia
# 223   26.70180  2009       8  Bolivia
# 224   39.98530  2009       9  Bolivia
# 225   64.76110  2009      10  Bolivia
# 226  102.22700  2009      11  Bolivia
# 227  173.78800  2009      12  Bolivia
# 228  208.90700  2010       1  Bolivia
# 229  183.61100  2010       2  Bolivia
# 230  145.20200  2010       3  Bolivia
# 231   37.84850  2010       4  Bolivia
# 232   58.89930  2010       5  Bolivia
# 233    7.69902  2010       6  Bolivia
# ..         ...   ...     ...      ...
# 270   75.58390  2013       7     Peru
# 271   78.40170  2013       8     Peru
# 272   74.53020  2013       9     Peru
# 273  145.31600  2013      10     Peru
# 274  143.21800  2013      11     Peru
# 275  152.09000  2013      12     Peru
# 276  159.06400  2014       1     Peru
# 277  149.26000  2014       2     Peru
# 278  193.84800  2014       3     Peru
# 279  172.67200  2014       4     Peru
# 280   91.75030  2014       5     Peru
# 281   74.13970  2014       6     Peru
# 282   71.67530  2014       7     Peru
# 283   77.69130  2014       8     Peru
# 284   83.26530  2014       9     Peru
# 285  108.85300  2014      10     Peru
# 286  127.26000  2014      11     Peru
# 287  174.06900  2014      12     Peru
# 288  154.38400  2015       1     Peru
# 289  182.30600  2015       2     Peru
# 290  187.53900  2015       3     Peru
# 291  179.83700  2015       4     Peru
# 292  109.17900  2015       5     Peru
# 293   68.57070  2015       6     Peru
# 294  102.38500  2015       7     Peru
# 295   58.21700  2015       8     Peru
# 296   57.64870  2015       9     Peru
# 297   64.10290  2015      10     Peru
# 298   99.11710  2015      11     Peru
# 299  151.33600  2015      12     Peru
#
# [288 rows x 4 columns]
